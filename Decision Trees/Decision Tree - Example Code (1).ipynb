# %% [markdown]
# 1. Loading the Data set

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X, y = iris.data, iris.target

# %% [markdown]
# -- viewing features names

# %%
print(iris['feature_names'])
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# -- The goal of our model is to classify between the 3 types mentioned in this picture.

# %%
from IPython.display import Image
Image(url='https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png')
# Out:
# <img src="https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png"/>

# %% [markdown]
# -- Viewing the data that we will work with.

# %%
import pandas as pd
import numpy as np

pd.DataFrame(data= np.c_[iris['data'], iris['target']],columns= iris['feature_names'] + ['target'])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %% [markdown]
# 2. We specify the model using the following parameters:
#
#
# > Criterion: ‘entropy’ as opposed to the default ‘Gini’ that is used in the default decision trees.
#
#
# If we ran the code as it is, it will create a decision tree that stops when each branch contains a 100% purity value, to stop the decision tree from making decision nodes, we can use the following parameters:
#
#
# > max_depth: to stop the decision tree from exceeding a certain depth.
#
#
# > min_impurity_decrease: to stop only when the impurity improvements are below a certain threshold
#
#
# > min_samples_split: to stop only when the samples left are less than a certain number.

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(criterion='entropy'
# , max_depth=2
# , min_impurity_decrease = 0.05
# , min_samples_split = 5
)
clf = clf.fit(X, y)

# %% [markdown]
# 3. Visualize the tree

# %%
import graphviz 
from sklearn import tree 

dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=iris.feature_names,  
                     class_names=iris.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
